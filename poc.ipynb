# %% [markdown]
# # Proof_of_concept of gitlab metadata extraction
# ---

# %%
import requests
print(requests.__version__)
# Out:
# 2.31.0

# %%
# REQUIRED PROP. META DATA FROM GITLAB REPO

import requests
from urllib.parse import urlparse, quote

def get_gitlab_metadata(repo_url, token=None):
    
    parsed = urlparse(repo_url)
    # print(f'### -------------- ### \nparsed: {parsed}')
    
    gitlab_host = f"{parsed.scheme}://{parsed.netloc}" # just the base URL (gitlab)
    # print(f'gitlab_host: {gitlab_host}')
    
    project_path = parsed.path.lstrip("/").removesuffix(".git") # making it api friendly
    # print(f'project_path: {project_path}')
    
    encoded_path = quote(project_path, safe="") # w/o slashes for API
    # print(f'encoded_path: {encoded_path}')
    
    api_base = f"{gitlab_host}/api/v4"
    # print(f'api_base: {api_base}\n### -------------- ###\n')

    headers = {"PRIVATE-TOKEN": token} if token else {} # tokens/pass for private repos [Only if needed]

    def fetch_json(endpoint):
        resp = requests.get(f"{api_base}{endpoint}", headers=headers, timeout=10)
        return resp.json() if resp.ok else {}

    project = fetch_json(f"/projects/{encoded_path}")
    print(f'project: {project}\n')
    
    languages = fetch_json(f"/projects/{encoded_path}/languages")
    tags = fetch_json(f"/projects/{encoded_path}/repository/tags")
    commit = fetch_json(f"/projects/{encoded_path}/repository/commits")
    branches = fetch_json(f"/projects/{encoded_path}/repository/branches")
    license = fetch_json(f"/projects/{encoded_path}/license")
    authors = fetch_json(f"/projects/{encoded_path}/repository/contributors")

    '''
    'get' can return (id, name, description, web_url, http_url_to_repo, readme_url, tag_list, topics, visibility, 
    created_at, last_activity_at, star_count, forks_count, open_issues_count, namespace, owner, container_registry_image_prefix)
    '''
    required = {
        "Name": project.get("name", "N/A"),
        "Description": project.get("description", "N/A"),
        "URL": project.get("web_url", "N/A"),
        "Clone URL": project.get("http_url_to_repo", "N/A"),
        "Languages": ", ".join(languages.keys()) if languages else "N/A",
        "Version": tags[0]["name"] if isinstance(tags, list) and tags else "No version tag",
    }

    recommended = {
        "Latest Commit": commit[0]["id"] if isinstance(commit, list) and commit else "N/A",
        "Branches": len(branches) if isinstance(branches, list) else "N/A",
        "License": license.get("name", "N/A") if isinstance(license, dict) else "N/A",
        "Authors": ", ".join([a["name"] for a in authors]) if isinstance(authors, list) else "N/A",
    }

    return {"required": required, "recommended": recommended}

if __name__ == "__main__":
    repos = [
        "https://gitlab.com/api4ai/examples/img-bg-removal-people.git",
        "https://gitlab.ub.uni-giessen.de/gc2052/machine-learning.git",
        "https://gitlab.com/QMAI/papers/adversarialkitaevchain.git"
    ]

    for r in repos:
        print(f"\nFetching metadata for: {r}")
        try:
            meta = get_gitlab_metadata(r)
            print(f'### Required Peoperties ###\n')
            for keys, values in meta["required"].items():
                print(f"{keys}: {values}")
            print(f"\n### Recommended Properties ###\n")
            for keys, values in meta["recommended"].items():
                print(f"{keys}: {values}")
        except Exception as e:
            print(f"Error: {e}")
# Out:
# Fetching metadata for: https://gitlab.com/api4ai/examples/img-bg-removal-people.git
# project: {'id': 45236194, 'description': 'API4AI is cloud-native computer vision & AI platform for startups, enterprises and individual developers. This repository contains sample mini apps that utilizes People Photo Background Removal API provided by API4AI.', 'name': 'People Photo Background Removal', 'name_with_namespace': 'api4ai / Examples / People Photo Background Removal', 'path': 'img-bg-removal-people', 'path_with_namespace': 'api4ai/examples/img-bg-removal-people', 'created_at': '2023-04-17T11:24:59.231Z', 'default_branch': 'main', 'tag_list': ['AI', 'api', 'api4ai', 'automation', 'computer vision', 'image processing', 'javascript', 'js', 'machine-learning', 'nodejs', 'python', 'shell', 'web'], 'topics': ['AI', 'api', 'api4ai', 'automation', 'computer vision', 'image processing', 'javascript', 'js', 'machine-learning', 'nodejs', 'python', 'shell', 'web'], 'ssh_url_to_repo': 'git@gitlab.com:api4ai/examples/img-bg-removal-people.git', 'http_url_to_repo': 'https://gitlab.com/api4ai/examples/img-bg-removal-people.git', 'web_url': 'https://gitlab.com/api4ai/examples/img-bg-removal-people', 'readme_url': 'https://gitlab.com/api4ai/examples/img-bg-removal-people/-/blob/main/README.md', 'forks_count': 0, 'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/45236194/a4a-logo-vertical-gradient-square-bg.png', 'star_count': 4, 'last_activity_at': '2025-10-24T12:39:36.042Z', 'visibility': 'public', 'namespace': {'id': 52113680, 'name': 'Examples', 'path': 'examples', 'kind': 'group', 'full_path': 'api4ai/examples', 'parent_id': 51786905, 'avatar_url': '/uploads/-/system/group/avatar/52113680/a4a-logo-vertical-gradient-square-bg.png', 'web_url': 'https://gitlab.com/groups/api4ai/examples'}}
#
# ### Required Peoperties ###
#
# Name: People Photo Background Removal
# Description: API4AI is cloud-native computer vision & AI platform for startups, enterprises and individual developers. This repository contains sample mini apps that utilizes People Photo Background Removal API provided by API4AI.
# URL: https://gitlab.com/api4ai/examples/img-bg-removal-people
# Clone URL: https://gitlab.com/api4ai/examples/img-bg-removal-people.git
# Languages: JavaScript, HTML, Python, Swift, C#
# Version: No version tag
#
# ### Recommended Properties ###
#
# Latest Commit: 76cdaec87618fcd6ebae2f2a47c61102a9aeca23
# Branches: 2
# License: N/A
# Authors: Vladislav Gubarev
#
# Fetching metadata for: https://gitlab.ub.uni-giessen.de/gc2052/machine-learning.git
# project: {'id': 770, 'description': None, 'name': 'Machine Learning', 'name_with_namespace': 'johannes bilk / Machine Learning', 'path': 'machine-learning', 'path_with_namespace': 'gc2052/machine-learning', 'created_at': '2023-03-22T11:47:34.556+01:00', 'default_branch': 'main', 'tag_list': [], 'topics': [], 'ssh_url_to_repo': 'git@gitlab.ub.uni-giessen.de:gc2052/machine-learning.git', 'http_url_to_repo': 'https://gitlab.ub.uni-giessen.de/gc2052/machine-learning.git', 'web_url': 'https://gitlab.ub.uni-giessen.de/gc2052/machine-learning', 'readme_url': 'https://gitlab.ub.uni-giessen.de/gc2052/machine-learning/-/blob/main/README.md', 'forks_count': 0, 'avatar_url': None, 'star_count': 0, 'last_activity_at': '2024-04-17T11:03:05.639+02:00', 'visibility': 'public', 'namespace': {'id': 1094, 'name': 'johannes bilk', 'path': 'gc2052', 'kind': 'user', 'full_path': 'gc2052', 'parent_id': None, 'avatar_url': None, 'web_url': 'https://gitlab.ub.uni-giessen.de/gc2052'}}
#
# ### Required Peoperties ###
#
# Name: Machine Learning
# Description: None
# URL: https://gitlab.ub.uni-giessen.de/gc2052/machine-learning
# Clone URL: https://gitlab.ub.uni-giessen.de/gc2052/machine-learning.git
# Languages: Jupyter Notebook, Python
# Version: No version tag
#
# ### Recommended Properties ###
#
# Latest Commit: b5240c61822c7399b8d4d05cbe777b253377630d
# Branches: 1
# License: N/A
# Authors: johannes bilk
#
# Fetching metadata for: https://gitlab.com/QMAI/papers/adversarialkitaevchain.git
# project: {'id': 43102587, 'description': 'Supplemenraty code for the publication "Adversarial Hamiltonian learning of quantum dots in a minimal Kitaev chain" by Rouven Koch,David van Driel, Alberto Bordin, Jose L. Lado, and Eliska Greplova.', 'name': 'AdversarialKitaevChain', 'name_with_namespace': 'Quantum Matter and AI / papers / AdversarialKitaevChain', 'path': 'adversarialkitaevchain', 'path_with_namespace': 'QMAI/papers/adversarialkitaevchain', 'created_at': '2023-02-01T14:32:25.943Z', 'default_branch': 'main', 'tag_list': [], 'topics': [], 'ssh_url_to_repo': 'git@gitlab.com:QMAI/papers/adversarialkitaevchain.git', 'http_url_to_repo': 'https://gitlab.com/QMAI/papers/adversarialkitaevchain.git', 'web_url': 'https://gitlab.com/QMAI/papers/adversarialkitaevchain', 'readme_url': 'https://gitlab.com/QMAI/papers/adversarialkitaevchain/-/blob/main/README.md', 'forks_count': 0, 'avatar_url': 'https://gitlab.com/uploads/-/system/project/avatar/43102587/Screenshot_2023-04-20_at_15.34.48.png', 'star_count': 0, 'last_activity_at': '2023-04-20T10:41:12.908Z', 'visibility': 'public', 'namespace': {'id': 10761343, 'name': 'papers', 'path': 'papers', 'kind': 'group', 'full_path': 'QMAI/papers', 'parent_id': 9529601, 'avatar_url': None, 'web_url': 'https://gitlab.com/groups/QMAI/papers'}}
#
# ### Required Peoperties ###
#
# Name: AdversarialKitaevChain
# Description: Supplemenraty code for the publication "Adversarial Hamiltonian learning of quantum dots in a minimal Kitaev chain" by Rouven Koch,David van Driel, Alberto Bordin, Jose L. Lado, and Eliska Greplova.
# URL: https://gitlab.com/QMAI/papers/adversarialkitaevchain
# Clone URL: https://gitlab.com/QMAI/papers/adversarialkitaevchain.git
# Languages: Jupyter Notebook, Python
# Version: No version tag
#
# ### Recommended Properties ###
#
# Latest Commit: 29eca26c153a588cf62f195d726a52c27cae2f34
# Branches: 1
# License: N/A
# Authors: Eliska Greplova, Rouven Koch
